# %% [markdown]
# ## 2.1 Writing a Proper Python Class
#
# ### 2.1.1 A basic implementation of the MSDie class

# %%
import random

class MSDie:
    """
    Multi-sided die

    Instance Variables:
        current_value
        num_sides

    """

    def __init__(self, num_sides):
        self.num_sides = num_sides
        self.current_value = self.roll()

    def roll(self):
        self.current_value = random.randrange(1,self.num_sides+1)
        return self.current_value

    def __str__(self):
        return str(self.current_value)

    def __repr__(self):
        return f"MSDie({self.num_sides}) : {self.current_value}"

# %%
my_die = MSDie(6)
for i in range(5):
    print(my_die)
    my_die.roll()
# Out:
# 4
# 3
# 3
# 4
# 6

# %%
d_list = [MSDie(6), MSDie(20)]
print(d_list)
# Out:
# [MSDie(6) : 1, MSDie(20) : 16]

# %% [markdown]
# *Notice that when we print a list of objects, the `repr` is used to display those objects.  Having a good `repr` makes it easier to debug with simple print statements.*

# %% [markdown]
# ### 2.2 Making your Class Comparable
#
# You might think it would be tedius to write all of the comparison functions but in fact it appears that just three are required. `__eq__`,` __lt__`, and `__le__`.
#
# So what is python doing? It is providing default implementations of some of the comparison operators in the parent class! It does this by writing them by calling the “dunder methods” directly and using logic.
